# %%
import pandas  #here we are imported the pandas library
data_frame = pandas.read_csv("data.csv")   #with .read_csv("location/name_of_the_file") it can read the csv file
data_frame.shape  #.shape shows you the shape of the data   #output:- (18207, 89)
# Out:
# (18207, 89)

# %%
data_frame.describe()  #it will help to get avarage of the data inside of the given file 
#it will give the output in th eform of : count, std, min, 25%, 50%, 75%, max
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data_frame.values     #it will give you all the data values in the form of arrays
#you will get each user data n an array
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       dtype=object)

# %%
# you can filter the data
data_frame[data_frame["Age"] == 25].head()    #here .head means only five of the data shown
# if we remove the .head() it will show all the filtered data
# Out:
#     Unnamed: 0      ID       Name  Age  \
# 9            9  200389   J. Oblak   25
# 43          43  201399  M. Icardi   25
# 45          45  195864   P. Pogba   25
# 47          47  192505  R. Lukaku   25
# 62          62  201535  R. Varane   25
#
#                                              Photo Nationality  \
# 9   https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 43  https://cdn.sofifa.org/players/4/19/201399.png   Argentina
# 45  https://cdn.sofifa.org/players/4/19/195864.png      France
# 47  https://cdn.sofifa.org/players/4/19/192505.png     Belgium
# 62  https://cdn.sofifa.org/players/4/19/201535.png      France
#
#                                    Flag  Overall  Potential  \
# 9   https://cdn.sofifa.org/flags/44.png       90         93
# 43  https://cdn.sofifa.org/flags/52.png       87         90
# 45  https://cdn.sofifa.org/flags/18.png       87         91
# 47   https://cdn.sofifa.org/flags/7.png       87         89
# ...
